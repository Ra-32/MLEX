# %% [markdown]
# <a href="https://colab.research.google.com/github/Ra-32/MLEX/blob/main/MLexample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df=df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1)

# %%
X_test.shape
# Out:
# (10, 2)

# %%
X_train.shape
# Out:
# (90, 2)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 1.34888431,  0.89290178],
#        [-0.49316146,  0.41108984],
#        [-0.23001206,  1.17184554],
#        [ 0.47171966,  0.18286313],
#        [-0.93174379,  1.85652567],
#        [ 0.03313733, -1.97261135],
#        [ 0.29628673,  0.13214608],
#        [ 1.17345138, -0.1721562 ],
#        [ 0.55943612, -0.0707221 ],
#        [-0.05457913, -0.42574143],
#        [ 0.1208538 ,  0.84218473],
#        [-0.23001206,  0.43644836],
#        [ 0.91030198, -1.49079941],
#        [ 0.1208538 , -0.501817  ],
#        [ 0.03313733,  0.66467507],
#        [ 0.20857026, -0.24823177],
#        [ 0.73486905, -0.27359029],
#        [-0.93174379,  0.28429722],
#        [ 0.47171966, -2.17547954],
#        [ 0.99801845,  0.71539212],
#        [-0.84402732, -0.12143915],
#        [-0.84402732, -1.51615793],
#        [ 0.29628673, -0.501817  ],
#        [-0.66859439,  0.96897735],
#        [-0.58087792, -0.22287324],
#        [-1.10717672, -1.79510169],
#        [-1.72119197, -0.57789257],
#        [-1.01946025,  0.46180689],
#        [ 0.91030198,  0.41108984],
#        [-0.23001206,  0.51252393],
#        [-1.37032611, -2.04868692],
#        [-0.93174379,  0.81682621],
#        [ 0.1208538 , -1.46544088],
#        [-0.84402732, -0.80611928],
#        [-0.49316146, -0.40038291],
#        [ 1.17345138, -1.84581873],
#        [ 0.99801845, -1.89653578],
#        [ 0.03313733,  0.03071199],
#        [-1.19489318,  0.5885995 ],
#        [-0.93174379,  0.71539212],
#        [-0.75631086, -1.44008236],
#        [ 0.82258552,  0.41108984],
#        [-1.80890844, -0.34966586],
#        [ 0.82258552,  0.38573132],
#        [ 2.22604896, -0.0707221 ],
#        [ 0.82258552, -0.67932666],
#        [ 1.34888431,  0.18286313],
#        [ 0.47171966,  0.94361883],
#        [ 0.91030198,  1.32399668],
#        [-0.93174379, -1.56687498],
#        [ 0.91030198, -0.27359029],
#        [-1.37032611,  0.66467507],
#        [ 1.43660077, -0.85683633],
#        [ 1.17345138,  0.36037279],
#        [-0.58087792, -0.04536358],
#        [-0.66859439, -0.32430734],
#        [ 1.8751831 ,  1.09576997],
#        [-0.66859439,  2.56656432],
#        [ 0.38400319,  0.46180689],
#        [-0.66859439, -0.8314778 ],
#        [-0.23001206,  0.23358018],
#        [-1.10717672, -0.04536358],
#        [ 1.78746663, -1.11042156],
#        [ 0.47171966, -0.8314778 ],
#        [ 0.55943612,  0.38573132],
#        [-0.49316146, -0.22287324],
#        [ 0.73486905,  0.00535347],
#        [-2.1597743 ,  2.79479103],
#        [-2.33520723,  1.52686486],
#        [ 0.73486905, -0.8314778 ],
#        [ 0.03313733, -0.52717552],
#        [ 0.1208538 ,  0.23358018],
#        [ 1.17345138, -0.9329119 ],
#        [-1.10717672, -0.90755337],
#        [-1.45804258,  1.95795976],
#        [ 0.73486905,  0.46180689],
#        [ 0.1208538 , -1.05970451],
#        [-0.66859439,  0.23358018],
#        [ 0.38400319, -0.1721562 ],
#        [-0.75631086,  0.13214608],
#        [ 0.64715259,  1.50150634],
#        [ 1.6120337 , -0.22287324],
#        [ 0.29628673,  0.10678756],
#        [-0.1422956 ,  0.48716541],
#        [-1.01946025,  1.0196944 ],
#        [ 2.05061603,  1.14648701],
#        [-0.49316146,  0.30965575],
#        [ 1.8751831 ,  0.66467507],
#        [-0.75631086,  1.3493552 ],
#        [-1.72119197, -1.21185565]])

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-0.93174379, -0.0707221 ],
#        [-0.1422956 ,  1.09576997],
#        [ 1.34888431, -1.56687498],
#        [ 0.91030198,  1.93260124],
#        [-1.01946025,  1.17184554],
#        [ 1.26116784,  0.23358018],
#        [ 1.43660077,  0.13214608],
#        [-1.01946025, -0.27359029],
#        [ 0.64715259,  0.79146769],
#        [ 0.03313733, -1.44008236]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
# model training
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)

# %%
y_test
# Out:
# 22    0
# 85    1
# 44    1
# 26    1
# 75    0
# 3     1
# 30    1
# 59    0
# 74    1
# 45    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >
